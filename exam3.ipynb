# %%
import ex1

ex1.func1()
# Out:
# '모듈에 있는 첫 번째 함수'

# %%
from ex1 import func1, func2

func1()
print(func2())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from ex1 import func1, func2
#       3 func1()
#       4 print(func2())
#
# ImportError: cannot import name 'func2' from 'ex1' (c:\Users\jieun\AppData\Local\Programs\Python\Python314\ex1.py)
