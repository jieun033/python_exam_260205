# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
import random
print(random.randint(1, 10))
# Out:
# 6

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2026-02-06 17:29:13.853977

# %%
import time

time.sleep(1)
print("1초 후 실행")
# Out:
# 1초 후 실행

# %%
import sys

print(sys.version)
# Out:
# 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]

# %%
import os

print(os.getcwd())
# Out:
# c:\pythonworks\py_exam

# %%
import json

data = {"name" : "jin", "age":19}
print(json.dumps(data))
# Out:
# {"name": "jin", "age": 19}

# %%
import re

# 문자열이 id로 시작하는지 확인
print(bool(re.match('id', 'id email')))
# Out:
# True

# %%
import csv

with open("test.csv", "w", newline="") as f:
    csv.writer(f).writerow(["name", "score"])

# %%
from collections import Counter
print(Counter("banana"))
# Out:
# Counter({'a': 3, 'n': 2, 'b': 1})
