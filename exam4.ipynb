# %%
import os

print(os.getcwd())

# %%
os.chdir("C://javaworks")
print(os.getcwd())
os.chdir("C://pythonworks")
print(os.getcwd())

# %%
os.listdir("C:\pythonworks")

for i in os.listdir("C:\pythonworks"):
    print(i)

# %%
print(os.path.exsists("C://pythonworks/py_test"))
print(os.path.exsists("C://pythonworks/py_exam"))

# %%
print(os.getcwd())

os.mkdir("py_test")
os.makedirs("C:/pythonworks/py_test2/py_test222")

# %%
os.rmdir("C:/pythonworks/py_test")
